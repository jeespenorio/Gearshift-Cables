# %%
import pandas as pd

#init data
data1 = {
    'Make':['CAN-AM'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05192'],
    
    'AD Item Number':['999769'],
    
    'Vendor Notes':['"OEM:707001721 LENGTH(FEET/ IN): LENGTH ( MM ): ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Defender MAX HD10 DPS',
'Defender MAX HD10 XT',
'Defender MAX HD10 XT CAB',
'Defender MAX HD10 Lone Star',
'Defender MAX HD10 X mr',
'Defender MAX HD10 Limited',
'Defender MAX HD8 DPS',
'Defender MAX HD8 XT',
'Defender MAX HD8'
]

#Range of Years

years = list(range(2017, 2020))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make                        Model Vendor Code  \
# 0   CAN-AM        Defender MAX HD10 DPS        NACH
# 1   CAN-AM         Defender MAX HD10 XT        NACH
# 2   CAN-AM     Defender MAX HD10 XT CAB        NACH
# 3   CAN-AM  Defender MAX HD10 Lone Star        NACH
# 4   CAN-AM       Defender MAX HD10 X mr        NACH
# 5   CAN-AM    Defender MAX HD10 Limited        NACH
# 6   CAN-AM         Defender MAX HD8 DPS        NACH
# 7   CAN-AM          Defender MAX HD8 XT        NACH
# 8   CAN-AM             Defender MAX HD8        NACH
# 9   CAN-AM        Defender MAX HD10 DPS        NACH
# 10  CAN-AM         Defender MAX HD10 XT        NACH
# 11  CAN-AM     Defender MAX HD10 XT CAB        NACH
# 12  CAN-AM  Defender MAX HD10 Lone Star        NACH
# 13  CAN-AM       Defender MAX HD10 X mr        NACH
# 14  CAN-AM    Defender MAX HD10 Limited        NACH
# 15  CAN-AM         Defender MAX HD8 DPS        NACH
# 16  CAN-AM          Defender MAX HD8 XT        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\1.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['ARCTIC CAT'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05193'],
    
    'AD Item Number':['999770'],
    
    'Vendor Notes':['"OEM:3307-520 LENGTH(FEET/ IN):5.74"" LENGTH ( MM ):1750MM ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Prowler 500'
]

#Range of Years

years = list(range(2017, 2023))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#          Make        Model Vendor Code                    Vendor Name  \
# 0  ARCTIC CAT  Prowler 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  ARCTIC CAT  Prowler 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  ARCTIC CAT  Prowler 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  ARCTIC CAT  Prowler 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4  ARCTIC CAT  Prowler 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5  ARCTIC CAT  Prowler 500        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#         MPN AD Item Number                                       Vendor Notes  \
# 0  AT-05193         999770  "OEM:3307-520 LENGTH(FEET/ IN):5.74"" LENGTH (...
# 1  AT-05193         999770  "OEM:3307-520 LENGTH(FEET/ IN):5.74"" LENGTH (...
# 2  AT-05193         999770  "OEM:3307-520 LENGTH(FEET/ IN):5.74"" LENGTH (...
# 3  AT-05193         999770  "OEM:3307-520 LENGTH(FEET/ IN):5.74"" LENGTH (...
# 4  AT-05193         999770  "OEM:3307-520 LENGTH(FEET/ IN):5.74"" LENGTH (...
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\2.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['ARCTIC CAT'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05194'],
    
    'AD Item Number':['999771'],
    
    'Vendor Notes':['"OEM:0487-099 LENGTH(FEET/ IN):6.03" LENGTH ( MM ):1840MM ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Prowler HDX 500 XT',
'HDX 500 XT',
'550 XT',
'Prowler XT 700',
'Prowler XT 550',
'Prowler XT 550i',
'Prowler HDX 700 XT',
'Prowler 700 XT'
]

#Range of Years

years = list(range(2017, 2023))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#           Make               Model Vendor Code                    Vendor Name  \
# 0   ARCTIC CAT  Prowler HDX 500 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   ARCTIC CAT          HDX 500 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   ARCTIC CAT              550 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   ARCTIC CAT      Prowler XT 700        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   ARCTIC CAT      Prowler XT 550        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5   ARCTIC CAT     Prowler XT 550i        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6   ARCTIC CAT  Prowler HDX 700 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7   ARCTIC CAT      Prowler 700 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8   ARCTIC CAT  Prowler HDX 500 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9   ARCTIC CAT          HDX 500 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# 10  ARCTIC CAT              550 XT        NACH  NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\3.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['ARCTIC CAT'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05195'],
    
    'AD Item Number':['999772'],
    
    'Vendor Notes':['"OEM:0487-059 LENGTH(FEET/ IN):4.16" LENGTH ( MM ):1270MM ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Prowler XT 650 4x4 Auto',
'Prowler XT 650 4x4 Auto M4',
'Prowler XT 650 H1',
'Prowler 550',
'Prowler XT 700',
'Prowler XTX 700 LE',
'Prowler XTX 700 H1 EFI',
'Prowler XT 550',
'Prowler XTX 700',
'Prowler XTX 700i',
'Prowler XT 550i'
]

#Range of Years

years = list(range(2009, 2015))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#           Make                       Model Vendor Code  \
# 0   ARCTIC CAT     Prowler XT 650 4x4 Auto        NACH
# 1   ARCTIC CAT  Prowler XT 650 4x4 Auto M4        NACH
# 2   ARCTIC CAT           Prowler XT 650 H1        NACH
# 3   ARCTIC CAT                 Prowler 550        NACH
# 4   ARCTIC CAT              Prowler XT 700        NACH
# ..         ...                         ...         ...
# 61  ARCTIC CAT      Prowler XTX 700 H1 EFI        NACH
# 62  ARCTIC CAT              Prowler XT 550        NACH
# 63  ARCTIC CAT             Prowler XTX 700        NACH
# 64  ARCTIC CAT            Prowler XTX 700i        NACH
# 65  ARCTIC CAT             Prowler XT 550i        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# 0   NACHMAN INTERNATIONAL CO. LTD  AT-05195         999772
# 1   NACHMAN INTERNATIONAL CO. LTD  AT-05195         999772
# 2   NACHMAN INTERNATIONAL CO. LTD  AT-05195         999772
# 3   NACHMAN INTERNATIONAL CO. LTD  AT-05195         999772
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\4.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['ARCTIC CAT'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05196'],
    
    'AD Item Number':['999773'],
    
    'Vendor Notes':['"OEM:0487-063 LENGTH(FEET/ IN):5.08" LENGTH ( MM ):1550MM ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Prowler XTZ 1000 H2 EFI',
'Prowler XTZ 1000 Baja',
'Prowler XTZ 1000',
'Prowler XTZ 1000i'
]

#Range of Years

years = list(range(2009, 2015))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#           Make                    Model Vendor Code  \
# 0   ARCTIC CAT  Prowler XTZ 1000 H2 EFI        NACH
# 1   ARCTIC CAT    Prowler XTZ 1000 Baja        NACH
# 2   ARCTIC CAT         Prowler XTZ 1000        NACH
# 3   ARCTIC CAT        Prowler XTZ 1000i        NACH
# 4   ARCTIC CAT  Prowler XTZ 1000 H2 EFI        NACH
# 5   ARCTIC CAT    Prowler XTZ 1000 Baja        NACH
# 6   ARCTIC CAT         Prowler XTZ 1000        NACH
# 7   ARCTIC CAT        Prowler XTZ 1000i        NACH
# 8   ARCTIC CAT  Prowler XTZ 1000 H2 EFI        NACH
# 9   ARCTIC CAT    Prowler XTZ 1000 Baja        NACH
# 10  ARCTIC CAT         Prowler XTZ 1000        NACH
# 11  ARCTIC CAT        Prowler XTZ 1000i        NACH
# 12  ARCTIC CAT  Prowler XTZ 1000 H2 EFI        NACH
# 13  ARCTIC CAT    Prowler XTZ 1000 Baja        NACH
# 14  ARCTIC CAT         Prowler XTZ 1000        NACH
# 15  ARCTIC CAT        Prowler XTZ 1000i        NACH
# 16  ARCTIC CAT  Prowler XTZ 1000 H2 EFI        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\5.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['CAN-AM'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05245'],
    
    'AD Item Number':['129452'],
    
    'Vendor Notes':['"OEM:707002000 LENGTH(FEET/ IN): LENGTH ( MM ):; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Maverick Trail 1000',
'Maverick Trail 800',
'Maverick Trail 800 DPS',
'Maverick Trail 1000 DPS',
'Maverick Sport 1000',
'Maverick Sport 1000 DPS',
'Maverick Sport 1000R DPS',
'Maverick Sport 1000R X rc',
'Maverick Sport 1000R X xc',
'Maverick Sport 1000R X mr',
'Commander 1000R Limited',
'Commander 1000R DPS'
]

#Range of Years

years = list(range(2018, 2024))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make                      Model Vendor Code  \
# 0   CAN-AM        Maverick Trail 1000        NACH
# 1   CAN-AM         Maverick Trail 800        NACH
# 2   CAN-AM     Maverick Trail 800 DPS        NACH
# 3   CAN-AM    Maverick Trail 1000 DPS        NACH
# 4   CAN-AM        Maverick Sport 1000        NACH
# ..     ...                        ...         ...
# 67  CAN-AM  Maverick Sport 1000R X rc        NACH
# 68  CAN-AM  Maverick Sport 1000R X xc        NACH
# 69  CAN-AM  Maverick Sport 1000R X mr        NACH
# 70  CAN-AM    Commander 1000R Limited        NACH
# 71  CAN-AM        Commander 1000R DPS        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# 0   NACHMAN INTERNATIONAL CO. LTD  AT-05245         129452
# 1   NACHMAN INTERNATIONAL CO. LTD  AT-05245         129452
# 2   NACHMAN INTERNATIONAL CO. LTD  AT-05245         129452
# 3   NACHMAN INTERNATIONAL CO. LTD  AT-05245         129452
# 4   NACHMAN INTERNATIONAL CO. LTD  AT-05245         129452
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\6.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['CAN-AM'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05246'],
    
    'AD Item Number':['129453'],
    
    'Vendor Notes':['"OEM:707002622 LENGTH(FEET/ IN): LENGTH ( MM ): ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Defender HD8',
'Defender HD8 DPS',
'Defender HD10',
'Defender HD10 DPS',
'Defender HD10 XT',
'Defender HD8 XT',
'Defender HD10 XT CAB',
'Defender HD10 Mossy Oak Hunting Edition',
'Defender HD5',
'Defender HD5 DPS',
'Defender HD8 XT CAB',
'Defender HD10 XT-P',
'Defender HD10 X mr'
]

#Range of Years

years = list(range(2020, 2024))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make                                    Model Vendor Code  \
# 0   CAN-AM                             Defender HD8        NACH
# 1   CAN-AM                         Defender HD8 DPS        NACH
# 2   CAN-AM                            Defender HD10        NACH
# 3   CAN-AM                        Defender HD10 DPS        NACH
# 4   CAN-AM                         Defender HD10 XT        NACH
# 5   CAN-AM                          Defender HD8 XT        NACH
# 6   CAN-AM                     Defender HD10 XT CAB        NACH
# 7   CAN-AM  Defender HD10 Mossy Oak Hunting Edition        NACH
# 8   CAN-AM                             Defender HD5        NACH
# 9   CAN-AM                         Defender HD5 DPS        NACH
# 10  CAN-AM                      Defender HD8 XT CAB        NACH
# 11  CAN-AM                       Defender HD10 XT-P        NACH
# 12  CAN-AM                       Defender HD10 X mr        NACH
# 13  CAN-AM                             Defender HD8        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\7.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['CAN-AM'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05247'],
    
    'AD Item Number':['129454'],
    
    'Vendor Notes':['"OEM:707001468, 707002227 LENGTH(FEET/ IN): LENGTH ( MM ): ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Defender HD8',
'Defender HD8 DPS',
'Defender HD10',
'Defender HD10 DPS',
'Defender HD10 XT',
'Defender HD8 XT',
'Defender HD10 XT CAB',
'Defender HD10 Mossy Oak Hunting Edition',
'Defender HD5',
'Defender HD5 DPS',
'Defender HD8 XT CAB',
'Defender HD10 XT-P',
'Defender HD10 X mr'
]

#Range of Years

years = list(range(2016, 2020))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make                                    Model Vendor Code  \
# 0   CAN-AM                             Defender HD8        NACH
# 1   CAN-AM                         Defender HD8 DPS        NACH
# 2   CAN-AM                            Defender HD10        NACH
# 3   CAN-AM                        Defender HD10 DPS        NACH
# 4   CAN-AM                         Defender HD10 XT        NACH
# 5   CAN-AM                          Defender HD8 XT        NACH
# 6   CAN-AM                     Defender HD10 XT CAB        NACH
# 7   CAN-AM  Defender HD10 Mossy Oak Hunting Edition        NACH
# 8   CAN-AM                             Defender HD5        NACH
# 9   CAN-AM                         Defender HD5 DPS        NACH
# 10  CAN-AM                      Defender HD8 XT CAB        NACH
# 11  CAN-AM                       Defender HD10 XT-P        NACH
# 12  CAN-AM                       Defender HD10 X mr        NACH
# 13  CAN-AM                             Defender HD8        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\8.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['CAN-AM'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05248'],
    
    'AD Item Number':['129455'],
    
    'Vendor Notes':['"OEM:707001809, 707002227 LENGTH(FEET/ IN): LENGTH ( MM ): ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Maverick X3 Turbo',
'Maverick X3 Turbo R',
'Maverick X3 900 HO'

]

#Range of Years

years = list(range(2016, 2020))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make                Model Vendor Code                    Vendor Name  \
# 0   CAN-AM    Maverick X3 Turbo        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   CAN-AM  Maverick X3 Turbo R        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   CAN-AM   Maverick X3 900 HO        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   CAN-AM    Maverick X3 Turbo        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   CAN-AM  Maverick X3 Turbo R        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5   CAN-AM   Maverick X3 900 HO        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6   CAN-AM    Maverick X3 Turbo        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7   CAN-AM  Maverick X3 Turbo R        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8   CAN-AM   Maverick X3 900 HO        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9   CAN-AM    Maverick X3 Turbo        NACH  NACHMAN INTERNATIONAL CO. LTD
# 10  CAN-AM  Maverick X3 Turbo R        NACH  NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\9.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05249'],
    
    'AD Item Number':['129456'],
    
    'Vendor Notes':['"OEM:7082235 LENGTH(FEET/ IN): LENGTH ( MM ): ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger 570',
'Ranger 570 Full-Size',
'Ranger 570 EPS'
'Ranger 570 Premium'


]

#Range of Years

years = list(range(2018, 2024))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#        Make                             Model Vendor Code  \
# 0   POLARIS                        Ranger 570        NACH
# 1   POLARIS              Ranger 570 Full-Size        NACH
# 2   POLARIS  Ranger 570 EPSRanger 570 Premium        NACH
# 3   POLARIS                        Ranger 570        NACH
# 4   POLARIS              Ranger 570 Full-Size        NACH
# 5   POLARIS  Ranger 570 EPSRanger 570 Premium        NACH
# 6   POLARIS                        Ranger 570        NACH
# 7   POLARIS              Ranger 570 Full-Size        NACH
# 8   POLARIS  Ranger 570 EPSRanger 570 Premium        NACH
# 9   POLARIS                        Ranger 570        NACH
# 10  POLARIS              Ranger 570 Full-Size        NACH
# 11  POLARIS  Ranger 570 EPSRanger 570 Premium        NACH
# 12  POLARIS                        Ranger 570        NACH
# 13  POLARIS              Ranger 570 Full-Size        NACH
# 14  POLARIS  Ranger 570 EPSRanger 570 Premium        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\10.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05250'],
    
    'AD Item Number':['129457'],
    
    'Vendor Notes':['"OEM:707002037 LENGTH(FEET/ IN):12.2" LENGTH ( MM ):3722MM; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Maverick X3 Max Turbo',
'Maverick X3 Max Turbo R',
'Maverick X3 Max X ds Turbo R',
'Maverick X3 Max X rs Turbo R',
'Maverick X3 Max DS Turbo R',
'Maverick X3 Max RS Turbo R',
'Maverick X3 Max X ds Turbo RR',
'Maverick X3 Max X rs Turbo RR',
'Maverick X3 Max X mr Turbo RR',
'Maverick X3 Max DS Turbo',
'Maverick X3 Max X rs Turbo RR Smart-Shox',
'Maverick X3 Max DS Turbo RR',
'Maverick X3 Max RS Turbo RR',
'Maverick Max 1000R DPS',
'Maverick Max 1000R Turbo',
'Maverick Max 1000R Turbo X ds',
'Maverick Max 1000R Turbo X rs',
'Maverick Max 1000R X mr'


]

#Range of Years

years = list(range(2017, 2024))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#         Make                          Model Vendor Code  \
# 0    POLARIS          Maverick X3 Max Turbo        NACH
# 1    POLARIS        Maverick X3 Max Turbo R        NACH
# 2    POLARIS   Maverick X3 Max X ds Turbo R        NACH
# 3    POLARIS   Maverick X3 Max X rs Turbo R        NACH
# 4    POLARIS     Maverick X3 Max DS Turbo R        NACH
# ..       ...                            ...         ...
# 121  POLARIS         Maverick Max 1000R DPS        NACH
# 122  POLARIS       Maverick Max 1000R Turbo        NACH
# 123  POLARIS  Maverick Max 1000R Turbo X ds        NACH
# 124  POLARIS  Maverick Max 1000R Turbo X rs        NACH
# 125  POLARIS        Maverick Max 1000R X mr        NACH
#
#                        Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO. LTD  AT-05250         129457
# 1    NACHMAN INTERNATIONAL CO. LTD  AT-05250         129457
# 2    NACHMAN INTERNATIONAL CO. LTD  AT-05250         129457
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\11.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05251'],
    
    'AD Item Number':['129458'],
    
    'Vendor Notes':['"OEM:707002270 LENGTH(FEET/ IN):12.2" LENGTH ( MM ):3722MM ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Maverick Sport Max 1000R DPS'


]

#Range of Years

years = list(range(2020, 2022))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make                         Model Vendor Code  \
# 0  POLARIS  Maverick Sport Max 1000R DPS        NACH
# 1  POLARIS  Maverick Sport Max 1000R DPS        NACH
#
#                      Vendor Name       MPN AD Item Number  \
# 0  NACHMAN INTERNATIONAL CO. LTD  AT-05251         129458
# 1  NACHMAN INTERNATIONAL CO. LTD  AT-05251         129458
#
#                                         Vendor Notes  Year
# 0  "OEM:707002270 LENGTH(FEET/ IN):12.2" LENGTH (...  2020
# 1  "OEM:707002270 LENGTH(FEET/ IN):12.2" LENGTH (...  2021

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\12.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['CAN-AM'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05252'],
    
    'AD Item Number':['129459'],
    
    'Vendor Notes':['"OEM:707002725 LENGTH(FEET/ IN): LENGTH ( MM ): ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Defender MAX HD10 DPS',
'Defender MAX HD8 DPS',
'Defender MAX HD8 XT',
'Defender MAX HD10 XT',
'Defender MAX HD8',
'Defender MAX HD10 XT CAB',
'Defender MAX HD10 Lone Star',
'Defender MAX HD10 X mr',
'Defender MAX HD10 Limited',
'Defender MAX HD9 DPS',
'Defender MAX HD9 XT',
'Defender MAX HD9',
'Defender PRO HD10'


]

#Range of Years

years = list(range(2020, 2024))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make                        Model Vendor Code  \
# 0   CAN-AM        Defender MAX HD10 DPS        NACH
# 1   CAN-AM         Defender MAX HD8 DPS        NACH
# 2   CAN-AM          Defender MAX HD8 XT        NACH
# 3   CAN-AM         Defender MAX HD10 XT        NACH
# 4   CAN-AM             Defender MAX HD8        NACH
# 5   CAN-AM     Defender MAX HD10 XT CAB        NACH
# 6   CAN-AM  Defender MAX HD10 Lone Star        NACH
# 7   CAN-AM       Defender MAX HD10 X mr        NACH
# 8   CAN-AM    Defender MAX HD10 Limited        NACH
# 9   CAN-AM         Defender MAX HD9 DPS        NACH
# 10  CAN-AM          Defender MAX HD9 XT        NACH
# 11  CAN-AM             Defender MAX HD9        NACH
# 12  CAN-AM            Defender PRO HD10        NACH
# 13  CAN-AM        Defender MAX HD10 DPS        NACH
# 14  CAN-AM         Defender MAX HD8 DPS        NACH
# 15  CAN-AM          Defender MAX HD8 XT        NACH
# 16  CAN-AM         Defender MAX HD10 XT        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\13.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['ARCTIC CAT'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05253'],
    
    'AD Item Number':['129460'],
    
    'Vendor Notes':['"OEM:0487-105, 0487-123 LENGTH(FEET/ IN): LENGTH ( MM ):  ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Prowler Pro',
'Prowler Pro XT',
'Prowler Pro Crew XT',
'Prowler Pro Crew Ranch Edition',
'Prowler Pro Ranch Edition',
'Prowler Pro Crew',
'Prowler Pro Crew LTD',
'Prowler Pro EPS',
'Prowler Pro Crew EPS',
'Prowler Pro LTD'


]

#Range of Years

years = list(range(2019, 2024))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#           Make                           Model Vendor Code  \
# 0   ARCTIC CAT                     Prowler Pro        NACH
# 1   ARCTIC CAT                  Prowler Pro XT        NACH
# 2   ARCTIC CAT             Prowler Pro Crew XT        NACH
# 3   ARCTIC CAT  Prowler Pro Crew Ranch Edition        NACH
# 4   ARCTIC CAT       Prowler Pro Ranch Edition        NACH
# 5   ARCTIC CAT                Prowler Pro Crew        NACH
# 6   ARCTIC CAT            Prowler Pro Crew LTD        NACH
# 7   ARCTIC CAT                 Prowler Pro EPS        NACH
# 8   ARCTIC CAT            Prowler Pro Crew EPS        NACH
# 9   ARCTIC CAT                 Prowler Pro LTD        NACH
# 10  ARCTIC CAT                     Prowler Pro        NACH
# 11  ARCTIC CAT                  Prowler Pro XT        NACH
# 12  ARCTIC CAT             Prowler Pro Crew XT        NACH
# 13  ARCTIC CAT  Prowler Pro Crew Ranch Edition        NACH
# 14  ARCTIC CAT       Prowler Pro Ranch Edition        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\14.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['KAWASAKI'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05254'],
    
    'AD Item Number':['129461'],
    
    'Vendor Notes':['"OEM:54010-0619 LENGTH(FEET/ IN): LENGTH ( MM ):  ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'KRF800 Teryx'


]

#Range of Years

years = list(range(2017, 2024))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#        Make         Model Vendor Code                    Vendor Name  \
# 0  KAWASAKI  KRF800 Teryx        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  KAWASAKI  KRF800 Teryx        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  KAWASAKI  KRF800 Teryx        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  KAWASAKI  KRF800 Teryx        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4  KAWASAKI  KRF800 Teryx        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5  KAWASAKI  KRF800 Teryx        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6  KAWASAKI  KRF800 Teryx        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#         MPN AD Item Number                                       Vendor Notes  \
# 0  AT-05254         129461  "OEM:54010-0619 LENGTH(FEET/ IN): LENGTH ( MM ...
# 1  AT-05254         129461  "OEM:54010-0619 LENGTH(FEET/ IN): LENGTH ( MM ...
# 2  AT-05254         129461  "OEM:54010-0619 LENGTH(FEET/ IN): LENGTH ( MM ...
# 3  AT-05254         129461  "OEM:54010-0619 LENGTH(FEET/ IN): LENGTH ( MM ...
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\15.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['YAMAHA'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05257'],
    
    'AD Item Number':['990397'],
    
    'Vendor Notes':['"OEM:B42-2637E-00 LENGTH(FEET/ IN): LENGTH ( MM ): ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'YXC700 Viking VI',
'YXC700 Viking VI EPS',
'YXC700 Viking VI EPS SE',
'YXC700 Viking VI EPS Ranch Edition',
'YXM700 Viking EPS SE',
'YXM700 Viking EPS with Suntop',
'YXM700 Viking with Suntop',
'YXM700 Viking EPS Ranch Edition'


]

#Range of Years

years = list(range(2016, 2024))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make                               Model Vendor Code  \
# 0   YAMAHA                    YXC700 Viking VI        NACH
# 1   YAMAHA                YXC700 Viking VI EPS        NACH
# 2   YAMAHA             YXC700 Viking VI EPS SE        NACH
# 3   YAMAHA  YXC700 Viking VI EPS Ranch Edition        NACH
# 4   YAMAHA                YXM700 Viking EPS SE        NACH
# ..     ...                                 ...         ...
# 59  YAMAHA  YXC700 Viking VI EPS Ranch Edition        NACH
# 60  YAMAHA                YXM700 Viking EPS SE        NACH
# 61  YAMAHA       YXM700 Viking EPS with Suntop        NACH
# 62  YAMAHA           YXM700 Viking with Suntop        NACH
# 63  YAMAHA     YXM700 Viking EPS Ranch Edition        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# 0   NACHMAN INTERNATIONAL CO. LTD  AT-05257         990397
# 1   NACHMAN INTERNATIONAL CO. LTD  AT-05257         990397
# 2   NACHMAN INTERNATIONAL CO. LTD  AT-05257         990397
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\16.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05372'],
    
    'AD Item Number':['127415'],
    
    'Vendor Notes':['"OEM:7081209 LENGTH(FEET/ IN):6ft 3 1/4" LENGTH ( MM ):1.912 M  ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger 2x4 500',
'Ranger 4x4 500',
'Ranger 4x4 500 EFI',
'Ranger 6x6 500',
'Ranger 6x6 700 EFI',
'Ranger XP 700',
'Ranger 4x4 700 EFI',
'Ranger MVRS 700 4x4',
'Ranger MVRS 700 6x6'


]

#Range of Years

years = list(range(2005, 2010))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#        Make                Model Vendor Code                    Vendor Name  \
# 0   POLARIS       Ranger 2x4 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   POLARIS       Ranger 4x4 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   POLARIS   Ranger 4x4 500 EFI        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   POLARIS       Ranger 6x6 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   POLARIS   Ranger 6x6 700 EFI        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5   POLARIS        Ranger XP 700        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6   POLARIS   Ranger 4x4 700 EFI        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7   POLARIS  Ranger MVRS 700 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8   POLARIS  Ranger MVRS 700 6x6        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9   POLARIS       Ranger 2x4 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# 10  POLARIS       Ranger 4x4 500        NACH  NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\17.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05373'],
    
    'AD Item Number':['127416'],
    
    'Vendor Notes':['"OEM:7081464 LENGTH(FEET/ IN):9FT 2 5/32" LENGTH ( MM ):2.80 M  ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'RRanger 700 Crew',
'Ranger MVRS 700 4x4'



]

#Range of Years

years = list(range(2008, 2010))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make                Model Vendor Code                    Vendor Name  \
# 0  POLARIS     RRanger 700 Crew        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  POLARIS  Ranger MVRS 700 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  POLARIS     RRanger 700 Crew        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  POLARIS  Ranger MVRS 700 4x4        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#         MPN AD Item Number                                       Vendor Notes  \
# 0  AT-05373         127416  "OEM:7081464 LENGTH(FEET/ IN):9FT 2 5/32" LENG...
# 1  AT-05373         127416  "OEM:7081464 LENGTH(FEET/ IN):9FT 2 5/32" LENG...
# 2  AT-05373         127416  "OEM:7081464 LENGTH(FEET/ IN):9FT 2 5/32" LENG...
# 3  AT-05373         127416  "OEM:7081464 LENGTH(FEET/ IN):9FT 2 5/32" LENG...
#
#    Year
# 0  2008
# 1  2008
# 2  2009
# 3  2009

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\18.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05374'],
    
    'AD Item Number':['127417'],
    
    'Vendor Notes':['"OEM:7081518 LENGTH(FEET/ IN):7FT 7 3/16" LENGTH ( MM ):2.316 M ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger 4x4 500 EFI',
'Ranger 700 Crew',
'Ranger XP 700',
'Ranger HD 700'




]

#Range of Years

years = list(range(2009, 2010))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make               Model Vendor Code                    Vendor Name  \
# 0  POLARIS  Ranger 4x4 500 EFI        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1  POLARIS     Ranger 700 Crew        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2  POLARIS       Ranger XP 700        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3  POLARIS       Ranger HD 700        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#         MPN AD Item Number                                       Vendor Notes  \
# 0  AT-05374         127417  "OEM:7081518 LENGTH(FEET/ IN):7FT 7 3/16" LENG...
# 1  AT-05374         127417  "OEM:7081518 LENGTH(FEET/ IN):7FT 7 3/16" LENG...
# 2  AT-05374         127417  "OEM:7081518 LENGTH(FEET/ IN):7FT 7 3/16" LENG...
# 3  AT-05374         127417  "OEM:7081518 LENGTH(FEET/ IN):7FT 7 3/16" LENG...
#
#    Year
# 0  2009
# 1  2009
# 2  2009
# 3  2009

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\19.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05376'],
    
    'AD Item Number':['127419'],
    
    'Vendor Notes':['"OEM:7081615 LENGTH(FEET/ IN):10FT 10 3/32" LENGTH ( MM ):3.305 M  ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger 4x4 500 EFI',
'Ranger 500 Crew',
'Ranger 500 Crew Turbo Silver LE',
'Ranger 500 Crew LE'





]

#Range of Years

years = list(range(2011, 2014))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#        Make                            Model Vendor Code  \
# 0   POLARIS               Ranger 4x4 500 EFI        NACH
# 1   POLARIS                  Ranger 500 Crew        NACH
# 2   POLARIS  Ranger 500 Crew Turbo Silver LE        NACH
# 3   POLARIS               Ranger 500 Crew LE        NACH
# 4   POLARIS               Ranger 4x4 500 EFI        NACH
# 5   POLARIS                  Ranger 500 Crew        NACH
# 6   POLARIS  Ranger 500 Crew Turbo Silver LE        NACH
# 7   POLARIS               Ranger 500 Crew LE        NACH
# 8   POLARIS               Ranger 4x4 500 EFI        NACH
# 9   POLARIS                  Ranger 500 Crew        NACH
# 10  POLARIS  Ranger 500 Crew Turbo Silver LE        NACH
# 11  POLARIS               Ranger 500 Crew LE        NACH
#
#                       Vendor Name       MPN AD Item Number  \
# 0   NACHMAN INTERNATIONAL CO. LTD  AT-05376         127419
# 1   NACHMAN INTERNATIONAL CO. LTD  AT-05376         127419
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\20.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05382'],
    
    'AD Item Number':['127423'],
    
    'Vendor Notes':['"OEM:7081614, 7081753 LENGTH(FEET/ IN):3FT 10 11/16" LENGTH ( MM ):1.187 M ; **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger 4x4 400',
'Ranger 4x4 500 EFI',
'Ranger 500 Crew',
'Ranger 500 Crew Turbo Silver LE',
'Ranger 500 EFI',
'Ranger 500 Crew LE'





]

#Range of Years

years = list(range(2010, 2015))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#        Make                            Model Vendor Code  \
# 0   POLARIS                   Ranger 4x4 400        NACH
# 1   POLARIS               Ranger 4x4 500 EFI        NACH
# 2   POLARIS                  Ranger 500 Crew        NACH
# 3   POLARIS  Ranger 500 Crew Turbo Silver LE        NACH
# 4   POLARIS                   Ranger 500 EFI        NACH
# 5   POLARIS               Ranger 500 Crew LE        NACH
# 6   POLARIS                   Ranger 4x4 400        NACH
# 7   POLARIS               Ranger 4x4 500 EFI        NACH
# 8   POLARIS                  Ranger 500 Crew        NACH
# 9   POLARIS  Ranger 500 Crew Turbo Silver LE        NACH
# 10  POLARIS                   Ranger 500 EFI        NACH
# 11  POLARIS               Ranger 500 Crew LE        NACH
# 12  POLARIS                   Ranger 4x4 400        NACH
# 13  POLARIS               Ranger 4x4 500 EFI        NACH
# 14  POLARIS                  Ranger 500 Crew        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\21.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05383'],
    
    'AD Item Number':['127424'],
    
    'Vendor Notes':['"OEM:7081829 LENGTH(FEET/ IN):8FT 9 31/32" LENGTH ( MM ):2.693 M  **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger 570',
'Ranger 570 EPS LE',
'Ranger 570 Crew',
'Ranger 570 Crew EPS LE',
'Ranger 570 EPS',
'Ranger 570 EPS Full-Size',
'Ranger 570 Full-Size',
'Ranger 570 Crew EPS',
'Ranger 570 Crew Full-Size',
'Ranger 570 Crew EPS Full-Size'





]

#Range of Years

years = list(range(2014, 2015))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make                          Model Vendor Code  \
# 0  POLARIS                     Ranger 570        NACH
# 1  POLARIS              Ranger 570 EPS LE        NACH
# 2  POLARIS                Ranger 570 Crew        NACH
# 3  POLARIS         Ranger 570 Crew EPS LE        NACH
# 4  POLARIS                 Ranger 570 EPS        NACH
# 5  POLARIS       Ranger 570 EPS Full-Size        NACH
# 6  POLARIS           Ranger 570 Full-Size        NACH
# 7  POLARIS            Ranger 570 Crew EPS        NACH
# 8  POLARIS      Ranger 570 Crew Full-Size        NACH
# 9  POLARIS  Ranger 570 Crew EPS Full-Size        NACH
#
#                      Vendor Name       MPN AD Item Number  \
# 0  NACHMAN INTERNATIONAL CO. LTD  AT-05383         127424
# 1  NACHMAN INTERNATIONAL CO. LTD  AT-05383         127424
# 2  NACHMAN INTERNATIONAL CO. LTD  AT-05383         127424
# 3  NACHMAN INTERNATIONAL CO. LTD  AT-05383         127424
# 4  NACHMAN INTERNATIONAL CO. LTD  AT-05383         127424
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\22.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05384'],
    
    'AD Item Number':['127425'],
    
    'Vendor Notes':['"OEM:7081830 LENGTH(FEET/ IN):11FT 6" LENGTH ( MM ):3.506 M  **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger 570',
'Ranger 570 EPS LE',
'Ranger 570 Crew',
'Ranger 570 Crew EPS LE',
'Ranger 570 EPS',
'Ranger 570 EPS Full-Size',
'Ranger 570 Full-Size',
'Ranger 570 Crew EPS',
'Ranger 570 Crew Full-Size',
'Ranger 570 Crew EPS Full-Size'





]

#Range of Years

years = list(range(2014, 2015))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make                          Model Vendor Code  \
# 0  POLARIS                     Ranger 570        NACH
# 1  POLARIS              Ranger 570 EPS LE        NACH
# 2  POLARIS                Ranger 570 Crew        NACH
# 3  POLARIS         Ranger 570 Crew EPS LE        NACH
# 4  POLARIS                 Ranger 570 EPS        NACH
# 5  POLARIS       Ranger 570 EPS Full-Size        NACH
# 6  POLARIS           Ranger 570 Full-Size        NACH
# 7  POLARIS            Ranger 570 Crew EPS        NACH
# 8  POLARIS      Ranger 570 Crew Full-Size        NACH
# 9  POLARIS  Ranger 570 Crew EPS Full-Size        NACH
#
#                      Vendor Name       MPN AD Item Number  \
# 0  NACHMAN INTERNATIONAL CO. LTD  AT-05384         127425
# 1  NACHMAN INTERNATIONAL CO. LTD  AT-05384         127425
# 2  NACHMAN INTERNATIONAL CO. LTD  AT-05384         127425
# 3  NACHMAN INTERNATIONAL CO. LTD  AT-05384         127425
# 4  NACHMAN INTERNATIONAL CO. LTD  AT-05384         127425
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\23.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05385'],
    
    'AD Item Number':['127426'],
    
    'Vendor Notes':['"OEM:7081620, 7081848 LENGTH(FEET/ IN):4FT 2 1/32" LENGTH ( MM ):1.271 M   **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'RZR 570',
'RZR 570 EPS Trail',
'RZR 570 EPS',
'RZR 570 Premium'






]

#Range of Years

years = list(range(2012, 2021))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#        Make              Model Vendor Code                    Vendor Name  \
# 0   POLARIS            RZR 570        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   POLARIS  RZR 570 EPS Trail        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   POLARIS        RZR 570 EPS        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   POLARIS    RZR 570 Premium        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   POLARIS            RZR 570        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5   POLARIS  RZR 570 EPS Trail        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6   POLARIS        RZR 570 EPS        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7   POLARIS    RZR 570 Premium        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8   POLARIS            RZR 570        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9   POLARIS  RZR 570 EPS Trail        NACH  NACHMAN INTERNATIONAL CO. LTD
# 10  POLARIS        RZR 570 EPS        NACH  NACHMAN INTERNATIONAL CO. LTD
# 11  POLARIS    RZR 570 Premium        NACH  NACHMAN INTERNATIONAL CO. LTD
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\24.csv"
final_df.to_csv(file_path, index = False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05390'],
    
    'AD Item Number':['127430'],
    
    'Vendor Notes':['"OEM:7081883 LENGTH(FEET/ IN):8ft 8 9/32" LENGTH ( MM ):2.648 M    **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger ETX',
'Ranger EV',
'Ranger EV Li-Ion',
'Ranger 570',
'Ranger 570 EPS Full-Size',
'Ranger 570 Full-Size',
'Ranger 570 Crew Full-Size',
'Ranger 570 Crew EPS Full-Size',
'Ranger 500'






]

#Range of Years

years = list(range(2015, 2023))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
    import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05390'],
    
    'AD Item Number':['127430'],
    
    'Vendor Notes':['"OEM:7081883 LENGTH(FEET/ IN):8ft 8 9/32" LENGTH ( MM ):2.648 M    **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger ETX',
'Ranger EV',
'Ranger EV Li-Ion',
'Ranger 570',
'Ranger 570 EPS Full-Size',
'Ranger 570 Full-Size',
'Ranger 570 Crew Full-Size',
'Ranger 570 Crew EPS Full-Size',
'Ranger 500'






]

#Range of Years

years = list(range(2015, 2023))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
    import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05390'],
    
    'AD Item Number':['127430'],
    
    'Vendor Notes':['"OEM:7081883 LENGTH(FEET/ IN):8ft 8 9/32" LENGTH ( MM ):2.648 M    **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger ETX',
'Ranger EV',
'Ranger EV Li-Ion',
'Ranger 570',
'Ranger 570 EPS Full-Size',
'Ranger 570 Full-Size',
'Ranger 570 Crew Full-Size',
'Ranger 570 Crew EPS Full-Size',
'Ranger 500'






]

#Range of Years

years = list(range(2015, 2023))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#   Cell In[137], line 61
#     import pandas as pd
#     ^
# IndentationError: unexpected indent

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\25.csv"
final_df.to_csv(file_path, index = False)

# %%
  import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05390'],
    
    'AD Item Number':['127430'],
    
    'Vendor Notes':['"OEM:7081883 LENGTH(FEET/ IN):8ft 8 9/32" LENGTH ( MM ):2.648 M    **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger 570',
'Ranger 570 EPS Full-Size',
'Ranger 570 Full-Size',
'Ranger 570 Crew Full-Size',
'Ranger 570 Crew EPS Full-Size',
'Ranger 500'



]

#Range of Years

years = list(range(2015, 2023))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#        Make                          Model Vendor Code  \
# 0   POLARIS                     Ranger 570        NACH
# 1   POLARIS       Ranger 570 EPS Full-Size        NACH
# 2   POLARIS           Ranger 570 Full-Size        NACH
# 3   POLARIS      Ranger 570 Crew Full-Size        NACH
# 4   POLARIS  Ranger 570 Crew EPS Full-Size        NACH
# 5   POLARIS                     Ranger 500        NACH
# 6   POLARIS                     Ranger 570        NACH
# 7   POLARIS       Ranger 570 EPS Full-Size        NACH
# 8   POLARIS           Ranger 570 Full-Size        NACH
# 9   POLARIS      Ranger 570 Crew Full-Size        NACH
# 10  POLARIS  Ranger 570 Crew EPS Full-Size        NACH
# 11  POLARIS                     Ranger 500        NACH
# 12  POLARIS                     Ranger 570        NACH
# 13  POLARIS       Ranger 570 EPS Full-Size        NACH
# 14  POLARIS           Ranger 570 Full-Size        NACH
# 15  POLARIS      Ranger 570 Crew Full-Size        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\26.csv"
final_df.to_csv(file_path, index = False)

# %%
  import pandas as pd

#init data
data1 = {
    'Make':['POLARIS'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05394'],
    
    'AD Item Number':['127433'],
    
    'Vendor Notes':['OEM:7081990, 7082475 LENGTH(FEET/ IN):11FFT 4 3/32" LENGTH ( MM ):3.457 M    **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Ranger 570',
'Ranger 570 EPS Full-Size',
'Ranger 570 Full-Size',
'Ranger 570 Crew Full-Size',
'Ranger 570 Crew EPS Full-Size'




]

#Range of Years

years = list(range(2015, 2024))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#        Make                          Model Vendor Code  \
# 0   POLARIS                     Ranger 570        NACH
# 1   POLARIS       Ranger 570 EPS Full-Size        NACH
# 2   POLARIS           Ranger 570 Full-Size        NACH
# 3   POLARIS      Ranger 570 Crew Full-Size        NACH
# 4   POLARIS  Ranger 570 Crew EPS Full-Size        NACH
# 5   POLARIS                     Ranger 570        NACH
# 6   POLARIS       Ranger 570 EPS Full-Size        NACH
# 7   POLARIS           Ranger 570 Full-Size        NACH
# 8   POLARIS      Ranger 570 Crew Full-Size        NACH
# 9   POLARIS  Ranger 570 Crew EPS Full-Size        NACH
# 10  POLARIS                     Ranger 570        NACH
# 11  POLARIS       Ranger 570 EPS Full-Size        NACH
# 12  POLARIS           Ranger 570 Full-Size        NACH
# 13  POLARIS      Ranger 570 Crew Full-Size        NACH
# 14  POLARIS  Ranger 570 Crew EPS Full-Size        NACH
# 15  POLARIS                     Ranger 570        NACH
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\27.csv"
final_df.to_csv(file_path, index = False)

# %%
  import pandas as pd

#init data
data1 = {
    'Make':['ARCTIC CAT'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05956'],
    
    'AD Item Number':['128278'],
    
    'Vendor Notes':['"OEM:0487-089 LENGTH(FEET/ IN):4.44" LENGTH ( MM ):1354MM ;   **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Wildcat Sport XT',
'Wildcat Sport Limited',
'Wildcat Sport SE',
'Wildcat Sport LTD',
'Wildcat X 1000',
'Wildcat X Limited',
'Wildcat X',
'Wildcat X SE',
'Wildcat X LTD',
'Wildcat XX',
'Wildcat XX LTD',
'Wildcat Trail XT',
'Wildcat Trail',
'Wildcat Trail Limited',
'Wildcat Trail SE',
'Wildcat Trail LTD'




]

#Range of Years

years = list(range(2014, 2021))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#            Make                  Model Vendor Code  \
# 0    ARCTIC CAT       Wildcat Sport XT        NACH
# 1    ARCTIC CAT  Wildcat Sport Limited        NACH
# 2    ARCTIC CAT       Wildcat Sport SE        NACH
# 3    ARCTIC CAT      Wildcat Sport LTD        NACH
# 4    ARCTIC CAT         Wildcat X 1000        NACH
# ..          ...                    ...         ...
# 107  ARCTIC CAT       Wildcat Trail XT        NACH
# 108  ARCTIC CAT          Wildcat Trail        NACH
# 109  ARCTIC CAT  Wildcat Trail Limited        NACH
# 110  ARCTIC CAT       Wildcat Trail SE        NACH
# 111  ARCTIC CAT      Wildcat Trail LTD        NACH
#
#                        Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO. LTD  AT-05956         128278
# 1    NACHMAN INTERNATIONAL CO. LTD  AT-05956         128278
# 2    NACHMAN INTERNATIONAL CO. LTD  AT-05956         128278
# 3    NACHMAN INTERNATIONAL CO. LTD  AT-05956         128278
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\28.csv"
final_df.to_csv(file_path, index = False)

# %%
  import pandas as pd

#init data
data1 = {
    'Make':['CAN-AM'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    'MPN':['AT-05957'],
    
    'AD Item Number':['128279'],
    
    'Vendor Notes':['"OEM:707001210, 707000775 LENGTH(FEET/ IN):4.46" LENGTH ( MM ):1.36 M ;   **GEARSHIFT CABLES REQUIRED IN POLARIS APPLICATIONS, RATHER THAN STANDARD UNIVERSAL JOINTED HARD LINKAGES FOUND IN OTHER OEM UTVS. ** SHIFT CABLES ARE KNOWN TO STRETCH OUTSIDE OF AVAILABLE FACTORY SHIFT-POINT  ADJUSTMENTS. AS WELL AS HAVING A WEAK POINT AT THE  W EARABLE LINKAGES.; **THESE GEARSHIFT CABLES ARE PRODUCED BY THE O.E.M    SUPPLIER, A CERTIFIED ISO/ TS16949 FACTORY. **MADE OF    BLACK PVC OUTER.   INSULATION ** INNER CORE IS COMPOSED OF SOLID STEEL TO REDUCE CABLE STRETCH AND COMPRESSION. ; "'],
}

#Lists of models

list_models = [
    
'Commander 1000R Limited',
'Commander 1000R DPS',
'Commander 1000R XT',
'Commander 1000R Mossy Oak Hunting Edition',
'Commander 1000R XT-P',
'Commander Max 1000 XT',
'Commander Max 1000 DPS',
'Commander Max 1000 Limited',
'Commander Max 1000R Limited',
'Commander Max 1000R DPS',
'Commander Max 1000R XT',
'Maverick 1000R',
'Maverick 1000R X rs',
'Maverick 1000R X rs DPS',
'Maverick 1000R X xc DPS',
'Maverick 1000R X mr DPS',
'Maverick 1000R X ds',
'Maverick 1000R Turbo X ds',
'Maverick 1000R XC',
'Maverick 1000R Turbo X rs',
'Maverick 1000R DPS',
'Maverick 1000R xc DPS',
'Maverick 1000R X xc',
'Maverick 1000R Turbo',
'Maverick 1000R X mr'



]

#Range of Years

years = list(range(2011, 2021))

#Function to generate DFs for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DFs for all sets of data
dfs= []
for year in years:
    df1 = pd.concat([generate_df(model, data1, year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate or Merge all dataframes
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#        Make                                      Model Vendor Code  \
# 0    CAN-AM                    Commander 1000R Limited        NACH
# 1    CAN-AM                        Commander 1000R DPS        NACH
# 2    CAN-AM                         Commander 1000R XT        NACH
# 3    CAN-AM  Commander 1000R Mossy Oak Hunting Edition        NACH
# 4    CAN-AM                       Commander 1000R XT-P        NACH
# ..      ...                                        ...         ...
# 245  CAN-AM                         Maverick 1000R DPS        NACH
# 246  CAN-AM                      Maverick 1000R xc DPS        NACH
# 247  CAN-AM                        Maverick 1000R X xc        NACH
# 248  CAN-AM                       Maverick 1000R Turbo        NACH
# 249  CAN-AM                        Maverick 1000R X mr        NACH
#
#                        Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO. LTD  AT-05957         128279
# ...

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\04_Section 05 - Cables ( 11-01-23 )\Merge\29.csv"
final_df.to_csv(file_path, index = False)
